# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from evaluation import make_dist
from data_processing import select_single_cone

# %%
data_dir = '../data'
train_dir = 'train'
test_dir = 'test'

file_mu_label = 'mu1'
train_pos_prop_label = '95'
train_neg_prop_label = '20'
train_prop_label = f'{train_neg_prop_label}{train_pos_prop_label}'
test_pos_prop_label = '95'
test_neg_prop_label = '20'
test_prop_label = f'{test_neg_prop_label}{test_pos_prop_label}'

# %%
# Load data
x = np.load(f'{data_dir}/{train_dir}/{file_mu_label}_{train_prop_label}_isoset.npy')
f = np.load(f'{data_dir}/{train_dir}/{file_mu_label}_{train_prop_label}_labels.npy')
x_test = np.load(f'{data_dir}/{test_dir}/{file_mu_label}_{test_prop_label}_isoset.npy')
f_test = np.load(f'{data_dir}/{test_dir}/{file_mu_label}_{test_prop_label}_labels.npy')
m_test = np.load(f'{data_dir}/{test_dir}/{test_prop_label}_M_set.npy')

# %%
# Some empty events end up being loaded as they aren't empty for
# other muon in event and remain in dataset, get rid of these
nonzeros = np.sum(x,axis=1) > 0
x = x[nonzeros]
f = f[nonzeros]
x_test = x_test[nonzeros_test]
f_test = f_test[nonzeros_test]
m_test = m_test[nonzeros_test]

# %% [markdown]
# # Test Mass Distribution

# %%
make_dist(m_test,50,'M (GeV)','Invariant Mass',_)

# %% [markdown]
# # Train - Valid Iso Full Distribution

# %%
make_dist(x.ravel(),50,'Iso','Train-Valid Isolations Full',_,log=True)

# %% [markdown]
# # Train - Valid Iso 95% Sig Distribution

# %%
make_dist(x[f==0.95].ravel(),50,'Iso','Train-Valid Isolations Full',_,log=True)

# %% [markdown]
# # Train - Valid Iso 20% Sig Distribution

# %%
make_dist(x[f==0.2].ravel(),50,'Iso','Train-Valid Isolations Full',_,log=True)

# %% [markdown]
# # Train - Valid Iso Distributions by Radius

# %%
for i in range(18):
    make_dist(select_single_cone(x,i),50,'Isolation',f'R={np.linspace(0.025,0.45,18)[i]}',_,log=True)

# %% [markdown]
# # Test Iso Full Distribution

# %%
make_dist(x_test.ravel(),50,'Iso','Train-Valid Isolations Full',_,log=True)

# %% [markdown]
# # Test Iso 95% Sig Distribution

# %%
make_dist(x_test[f_test==0.95].ravel(),50,'Iso','Test Isolations Full',_,log=True)

# %% [markdown]
# # Test Iso 20% Sig Distribution

# %%
make_dist(x_test[f_test==0.2].ravel(),50,'Iso','Test Isolations Full',_,log=True)

# %% [markdown]
# # Test Iso Distributions by Radius

# %%
for i in range(18):
    make_dist(select_single_cone(x_test,i),50,'Isolation',f'R={np.linspace(0.025,0.45,18)[i]}',_,log=True)
